# %% [markdown]
# # Loops

# %%
# For loop

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# range(start, stop, stepsize)

for i in range(0, 11 , 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
str = "Shivam"

for i in str:
    print(i)
# Out:
# S
# h
# i
# v
# a
# m

# %%
# While Loop
# The while loop continues to run until the condition is true...

count = 0
while count <5:
    print(count)
    count = count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
 # Loop control statements

# Break
# The break statement exits form the loop permanently

# Break statement
for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Continue Statement

# the continue statement skips the current iteration and continues with thw next.

for i in range(10):
    if i ==5:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
# Pass Statement
# The pass statement is used to do noting, used for null operation

for i in range(5):
    pass

# %%
# Nested loop
# a loop inside a loop

for i in range(3):
    for j in range(2):
        print(f"i: {i} and j: {j}")
# Out:
# i: 0 and j: 0
# i: 0 and j: 1
# i: 1 and j: 0
# i: 1 and j: 1
# i: 2 and j: 0
# i: 2 and j: 1

# %%
# Calculate the sum of first n natural numbers

n = 10

sum = 0

count = 0
while(count<=n):
    sum = sum + count
    count = count + 1
print(f"The sum of first 10 natural number is {sum}")
# Out:
# The sum of first 10 natural number is 55
